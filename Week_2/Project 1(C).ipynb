# %% [markdown]
# START
# input Name 1, Name 2
# input Name 1 = age 1
# input Name 2 = age 2
# SWAP age of Name 1 and Name 2 using temp variable
# input temp variable = Name 1
# input Name 1 = Name 2
# input Name 2 = temp
# Print "Name1, Name 2"
# STOP
