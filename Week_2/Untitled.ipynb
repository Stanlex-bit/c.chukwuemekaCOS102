# %% [markdown]
# START
# If: you have an account with us, then provide name and pay with account
# Else If: you do not have an account with us, then pay with Card or Transfer
# COMPUTE:Do items on receipt match with items bought?
# If yes
